# %%
using Plots

# %%
f(x) = x^2
# Out:
# f (generic function with 1 method)

# %%
plot(f)

# %%
plot(f, 0, 10)

# %%
x = rand(10,10)
# Out:
# 10×10 Array{Float64,2}:
#  0.843959  0.43303   0.498013   0.136005    …  0.358773  0.793451   0.183345
#  0.58373   0.20514   0.947186   0.539737       0.10088   0.127109   0.899019
#  0.327197  0.746676  0.515504   0.819308       0.084908  0.348749   0.770763
#  0.217783  0.382896  0.384575   0.00967762     0.276972  0.124499   0.743745
#  0.473837  0.323412  0.288923   0.336207       0.571012  0.230847   0.953485
#  0.373223  0.92173   0.612345   0.54606     …  0.354717  0.618171   0.0424294
#  0.85087   0.24926   0.0169352  0.597997       0.525034  0.973367   0.676736
#  0.423622  0.53283   0.60524    0.102462       0.563106  0.117196   0.738591
#  0.6426    0.667385  0.518048   0.0716706      0.690846  0.0512294  0.806749
#  0.643615  0.469248  0.984525   0.300259       0.440055  0.91848    0.690359

# %%
scatter(x)

# %%
plot(x -> x^3)

# %%
plot(rand(10,10))
