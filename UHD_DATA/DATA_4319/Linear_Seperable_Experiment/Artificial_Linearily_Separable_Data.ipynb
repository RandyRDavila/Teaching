# %% [markdown]
# # DATA 4319: Statistical & Machine Learning
#
# ## Lecture 2: Artificial Linearily Separable Data
#
# In this notebook we will generate an artificial collection of linearily seperable data points. Such collections can be useful when testing machine learning algorithms.
#
# For this notebook you will need to import the following packages:
# * Plots [documentation](http://docs.juliaplots.org/latest/)

# %%
using Plots

# %% [markdown]
# The idea can be summarized below:
# 1. Create a linear function whose graph passed through $[0,1]\times[0,1]$.
# 2. Generate random data points in $[0,1]\times[0,1]$.
# 3. Seperate these data points into two sets, one of which lies above the line and the other below.

# %%
# Generate a random linear function
coeff = rand(2)
y(x) = coeff[1]*x + coeff[2]

# Generate random tuples of data
X = rand(100, 2)
D = [(X[i,1], X[i,2]) for i = 1:100]
# Out:
# 100-element Array{Tuple{Float64,Float64},1}:
#  (0.2004760891873203, 0.600934820705511)
#  (0.3429474912926178, 0.4387619994842189)
#  (0.18077143534809115, 0.993197969585369)
#  (0.005185650299601052, 0.05787288776231292)
#  (0.35778877965237843, 0.8868062778351573)
#  (0.6636198773945179, 0.029903062168304295)
#  (0.41626315551701665, 0.17222639159286746)
#  (0.4630332535343846, 0.0501984606033532)
#  (0.7541620701743146, 0.4322177878619007)
#  (0.5541245810532978, 0.31575099205271706)
#  (0.2875089802634183, 0.6751174431844482)
#  (0.9079822823556429, 0.7383538635492937)
#  (0.6207063903443955, 0.13897269888046315)
#  ⋮
#  (0.22912199620145168, 0.2375320245706367)
#  (0.3583989371599907, 0.4363687201070139)
#  (0.9763296868465259, 0.1756604833501887)
#  (0.603682917787117, 0.02831768812753599)
#  (0.06631599581903758, 0.15768722651711897)
#  (0.622370586029809, 0.5070684248250867)
#  (0.43046164086418925, 0.9683509759454678)
#  (0.7420151811428337, 0.8753024879750093)
#  (0.2466888344800806, 0.8301123789246865)
#  (0.972357343966572, 0.2606591552633071)
#  (0.6879891621927197, 0.7222279272383467)
#  (0.21824233609542265, 0.5799782782490948)

# %%
# above will store data points above the random linear function
above = []

# below will store data points below the random linear function 
below = []

for data in D
    if y(data[1]) < data[2]
        push!(above, data)
    else
        push!(below, data)
    end
end

# %%
scatter([x for x in above], label = "upper data")
scatter!([x for x in below], label = "lower data")
plot!(y, label = "seperator")

# %%
# Condense this idea into a simple function 
function make_linearily_separable_data(n)
    coeff = rand(2)
    X = rand(n,2)
    above = []
    below = []
    
    for i = 1:n
        if coeff[1]*X[i,1] + coeff[2] < X[i,2]
            push!(above, (X[i,1], X[i,2]))
        end
        if coeff[1]*X[i,1] + coeff[2] > X[i,2]
            push!(below, (X[i,1], X[i,2]))
        end
    end
    
    return above, below, coeff
end
# Out:
# make_linearily_separable_data (generic function with 1 method)

# %%
D1, D2, coeff = make_linearily_separable_data(100)
scatter([x for x in D1], label = "upper")
scatter!([x for x in D2], label = "lower")
plot!(x->coeff[1]*x + coeff[2], label = "y(x)")
