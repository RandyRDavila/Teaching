# %% [markdown]
# # DATA 4319: Statistical & Machine Learning
#
# ## Lecture 2: Artificial Linearily Seperable Data
#
# In this notebook we will generate an artificial collection of linearily seperable data points. Such collections can be useful when testing machine learning algorithms.
#
# For this notebook you will need to import the following packages:
# * Plots [documentation](http://docs.juliaplots.org/latest/)

# %%
using Plots

# %% [markdown]
# The idea can be summarized below:
# 1. Create a linear function whose graph passed through $[0,1]\times[0,1]$.
# 2. Generate random data points in $[0,1]\times[0,1]$.
# 3. Seperate these data points into two sets, one of which lies above the line and the other below.

# %%
# Generate a random linear function
coeff = rand(2)
y(x) = coeff[1]*x + coeff[2]

# Generate random tuples of data
X = rand(100, 2)
D = [(X[i,1], X[i,2]) for i = 1:100]
# Out:
# 100-element Array{Tuple{Float64,Float64},1}:
#  (0.5145087359127762, 0.6377271659409454)
#  (0.9520712172422456, 0.7218732455007857)
#  (0.2668065039047549, 0.9019232640131059)
#  (0.12321642002426914, 0.5692144350908339)
#  (0.9102094214238552, 0.8378608923390412)
#  (0.8916819107921887, 0.33401565102385966)
#  (0.539701932449919, 0.07392248301803206)
#  (0.7002441596561482, 0.18069731068763617)
#  (0.7569216663298322, 0.7351356294603193)
#  (0.48886988379409413, 0.6734530657076101)
#  (0.05508142561454754, 0.10008870745793419)
#  (0.4212077303620543, 0.5261609939458018)
#  (0.5285961752193913, 0.33385275345104315)
#  ⋮
#  (0.2963583674069401, 0.4966084827831472)
#  (0.42965666414819603, 0.36682603338105246)
#  (0.3516260859852771, 0.9196911059078199)
#  (0.6821155383340254, 0.4747793560029321)
#  (0.9222427387065057, 0.69825892574561)
#  (0.8903177606389909, 0.14258133010418073)
#  (0.021576775739586607, 0.3249313370813083)
#  (0.01508216094428505, 0.6300014724078007)
#  (0.9170863341903293, 0.4470132810540304)
#  (0.3124367774255612, 0.11822205459277635)
#  (0.900691406062001, 0.7938849664524534)
#  (0.4138751669057603, 0.024477498127856823)

# %%
# above will store data points above the random linear function
above = []

# below will store data points below the random linear function 
below = []

for data in D
    if y(data[1]) < data[2]
        push!(above, data)
    else
        push!(below, data)
    end
end

# %%
scatter([x for x in above], label = "upper data")
scatter!([x for x in below], label = "lower data")
plot!(y, label = "seperator")

# %%
# Condense this idea into a simple function 
function make_linearily_seperable_data(n)
    coeff = rand(n)
    X = rand(n,2)
    above = []
    below = []
    
    for i = 1:n
        if coeff[1]*X[i,1] + coeff[2] < X[i,2]
            push!(above, (X[i,1], X[i,2]))
        end
        if coeff[1]*X[i,1] + coeff[2] > X[i,2]
            push!(below, (X[i,1], X[i,2]))
        end
    end
    
    return [above, below]
end

# %%
D = make_linearily_seperable_data(100)
scatter([x for x in D[1]])
scatter!([x for x in D[2]])
