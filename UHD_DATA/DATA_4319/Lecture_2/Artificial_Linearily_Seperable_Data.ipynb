# %% [markdown]
# # DATA 4319: Statistical & Machine Learning
#
# ## Lecture 2: Artificial Linearily Seperable Data
#
# In this notebook we will generate an artificial collection of linearily seperable data points. Such collections can be useful when testing machine learning algorithms.
#
# For this notebook you will need to import the following packages:
# * Plots [documentation](http://docs.juliaplots.org/latest/)

# %%
using Plots

# %% [markdown]
# The idea can be summarized below:
# 1. Create a linear function whose graph passed through $[0,1]\times[0,1]$.
# 2. Generate random data points in $[0,1]\times[0,1]$.
# 3. Seperate these data points into two sets, one of which lies above the line and the other below.

# %%
# Generate a random linear function
coeff = rand(2)
y(x) = coeff[1]*x + coeff[2]

# Generate random tuples of data
X = rand(100, 2)
D = [(X[i,1], X[i,2]) for i = 1:100]
# Out:
# 100-element Array{Tuple{Float64,Float64},1}:
#  (0.036929803373681125, 0.8539933894472174)
#  (0.7867686260025004, 0.794030716676525)
#  (0.8236158137983034, 0.7464375743683669)
#  (0.413345611424798, 0.7702754213708309)
#  (0.43729795018222206, 0.14794278964151042)
#  (0.6321205711140785, 0.610213950178607)
#  (0.2369392997406483, 0.2952769566918836)
#  (0.4482737355484767, 0.9979320016967157)
#  (0.8645574124999311, 0.9612654499491529)
#  (0.49922030706825393, 0.14234155422073402)
#  (0.2541819703928925, 0.03975293415300718)
#  (0.027314504724915256, 0.9458128288625001)
#  (0.38370304273043887, 0.6909459412971835)
#  ⋮
#  (0.8089223585094818, 0.03692069253829633)
#  (0.3353183654195424, 0.25997808700669545)
#  (0.7246886537190873, 0.2539068430849267)
#  (0.8309503346294096, 0.2786983539167096)
#  (0.033801953374640537, 0.008410607784780089)
#  (0.24413540329946026, 0.10917655257669145)
#  (0.0214387956669575, 0.3762138334787344)
#  (0.6473743984324225, 0.6925279514339182)
#  (0.6578874218952078, 0.6334605408749794)
#  (0.6425189462056566, 0.8122747649051794)
#  (0.08819261096398456, 0.19807140288207958)
#  (0.34134938214957256, 0.05027021271040244)

# %%
# above will store data points above the random linear function
above = []

# below will store data points below the random linear function 
below = []

for data in D
    if y(data[1]) < data[2]
        push!(above, data)
    else
        push!(below, data)
    end
end

# %%
scatter([x for x in above], label = "upper data")
scatter!([x for x in below], label = "lower data")
plot!(y, label = "seperator")

# %%
# Condense this idea into a simple function 
function make_linearily_seperable_data(n)
    coeff = rand(n)
    X = rand(n,2)
    above = []
    below = []
    
    for i = 1:n
        if coeff[1]*X[i,1] + coeff[2] < X[i,2]
            push!(above, (X[i,1], X[i,2]))
        end
        if coeff[1]*X[i,1] + coeff[2] > X[i,2]
            push!(below, (X[i,1], X[i,2]))
        end
    end
    
    return [above, below]
end
# Out:
# make_linearily_seperable_data (generic function with 1 method)

# %%
D = make_linearily_seperable_data(20)
scatter([x for x in D[1]])
scatter!([x for x in D[2]])
