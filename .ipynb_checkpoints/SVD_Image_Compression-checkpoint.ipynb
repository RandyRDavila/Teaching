# %% [markdown]
# # SVD and Image Compression
# In this notebook we show how the SVD can be used to compress images. With this aim in mind, it should be noted that images can be represented as multidimensional arrays of numbers, i.e., matrices.

# %%
using LinearAlgebra, Images, TestImages

# %%
# Load a sample test image 
img = testimage("cameraman")
# Out:
# 512×512 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.616)  …  Gray{N0f8}(0.596)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.616)     Gray{N0f8}(0.596)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.616)     Gray{N0f8}(0.596)
#  Gray{N0f8}(0.627)  Gray{N0f8}(0.616)     Gray{N0f8}(0.596)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.616)     Gray{N0f8}(0.596)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.616)  …  Gray{N0f8}(0.6)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.616)     Gray{N0f8}(0.6)
#  Gray{N0f8}(0.627)  Gray{N0f8}(0.616)     Gray{N0f8}(0.6)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.608)     Gray{N0f8}(0.596)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.604)     Gray{N0f8}(0.596)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.604)  …  Gray{N0f8}(0.596)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.608)     Gray{N0f8}(0.596)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.604)     Gray{N0f8}(0.588)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.51)   Gray{N0f8}(0.49)   …  Gray{N0f8}(0.384)
#  Gray{N0f8}(0.443)  Gray{N0f8}(0.463)     Gray{N0f8}(0.4)
#  Gray{N0f8}(0.396)  Gray{N0f8}(0.431)     Gray{N0f8}(0.404)
#  Gray{N0f8}(0.384)  Gray{N0f8}(0.416)     Gray{N0f8}(0.412)
#  Gray{N0f8}(0.435)  Gray{N0f8}(0.439)     Gray{N0f8}(0.439)
#  Gray{N0f8}(0.494)  Gray{N0f8}(0.475)  …  Gray{N0f8}(0.467)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.482)     Gray{N0f8}(0.451)
#  Gray{N0f8}(0.447)  Gray{N0f8}(0.486)     Gray{N0f8}(0.431)
#  Gray{N0f8}(0.455)  Gray{N0f8}(0.482)     Gray{N0f8}(0.427)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.482)     Gray{N0f8}(0.435)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.482)  …  Gray{N0f8}(0.435)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.482)     Gray{N0f8}(0.435)

# %%
# Convert the image to a matrix pf floating point numbers
A = float(channelview(img))
# Out:
# 512×512 Array{Float32,2}:
#  0.611765  0.615686  0.627451  0.623529  …  0.596078  0.596078  0.596078
#  0.611765  0.615686  0.623529  0.619608     0.596078  0.596078  0.596078
#  0.619608  0.615686  0.611765  0.611765     0.596078  0.596078  0.596078
#  0.627451  0.615686  0.603922  0.603922     0.6       0.596078  0.596078
#  0.619608  0.615686  0.611765  0.611765     0.6       0.596078  0.596078
#  0.611765  0.615686  0.623529  0.623529  …  0.6       0.6       0.6
#  0.619608  0.615686  0.611765  0.611765     0.6       0.6       0.6
#  0.627451  0.615686  0.603922  0.603922     0.6       0.6       0.6
#  0.619608  0.607843  0.6       0.6          0.596078  0.596078  0.596078
#  0.611765  0.603922  0.6       0.6          0.592157  0.596078  0.596078
#  0.607843  0.603922  0.603922  0.6       …  0.588235  0.596078  0.596078
#  0.607843  0.607843  0.607843  0.603922     0.592157  0.596078  0.596078
#  0.607843  0.603922  0.6       0.6          0.592157  0.588235  0.588235
#  ⋮                                       ⋱            ⋮
#  0.509804  0.490196  0.466667  0.466667  …  0.364706  0.380392  0.384314
#  0.443137  0.462745  0.482353  0.482353     0.360784  0.392157  0.4
#  0.396078  0.431373  0.462745  0.462745     0.403922  0.4       0.403922
#  0.384314  0.415686  0.447059  0.447059     0.458824  0.419608  0.411765
#  0.435294  0.439216  0.443137  0.45098      0.470588  0.447059  0.439216
#  0.494118  0.47451   0.454902  0.466667  …  0.478431  0.470588  0.466667
#  0.47451   0.482353  0.490196  0.490196     0.486275  0.458824  0.45098
#  0.447059  0.486275  0.521569  0.509804     0.490196  0.443137  0.431373
#  0.454902  0.482353  0.509804  0.501961     0.482353  0.439216  0.427451
#  0.47451   0.482353  0.494118  0.494118     0.47451   0.443137  0.435294
#  0.47451   0.482353  0.494118  0.494118  …  0.47451   0.443137  0.435294
#  0.47451   0.482353  0.494118  0.494118     0.47451   0.443137  0.435294

# %% [markdown]
# Next we use the svd function from the LinearAlgebra library to find the SVD factorization of A.

# %%
# Compute the SVD-factorization 
F = svd(A)
# Out:
# SVD{Float32,Float32,Array{Float32,2}}(Float32[-0.0584775 -0.0655369 … -0.0365227 -0.0584804; -0.0584807 -0.0654969 … -0.0356943 0.114971; … ; -0.0392299 -0.00910872 … 0.0406806 0.0807052; -0.0392245 -0.00935623 … 0.015571 0.0254526], Float32[250.467, 56.8278, 42.9653, 24.3121, 22.9592, 18.9221, 18.0009, 14.1627, 13.1267, 12.3274  …  0.000674781, 0.000639252, 0.000474822, 0.000459474, 0.00034819, 0.000319281, 0.000259251, 0.000187583, 0.000130626, 4.30659e-5], Float32[-0.0502391 -0.0503994 … -0.046726 -0.0467009; 0.0269879 0.027083 … 0.0223417 0.022396; … ; 0.0 0.0224355 … -0.0512417 0.0607833; 0.0 0.0182721 … 0.0360433 -0.0690453])

# %%
# Set the diagonal
Σ = Diagonal(F.S)
# Out:
# 512×512 Diagonal{Float32,Array{Float32,1}}:
#  250.467    ⋅        ⋅        ⋅        ⋅      …   ⋅            ⋅
#     ⋅     56.8278    ⋅        ⋅        ⋅          ⋅            ⋅
#     ⋅       ⋅      42.9653    ⋅        ⋅          ⋅            ⋅
#     ⋅       ⋅        ⋅      24.3121    ⋅          ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅      22.9592      ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅      …   ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅          ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅          ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅          ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅          ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅      …   ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅          ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅          ⋅            ⋅
#    ⋮                                          ⋱  ⋮
#     ⋅       ⋅        ⋅        ⋅        ⋅      …   ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅          ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅          ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅          ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅          ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅      …   ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅          ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅          ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅          ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅          ⋅            ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅      …  0.000130626   ⋅
#     ⋅       ⋅        ⋅        ⋅        ⋅          ⋅           4.30659e-5

# %%
test = F.U[:,1:2]*Σ[1:2,1:2]*F.Vt[1:2, :]
colorview(Gray, test)
# Out:
# 512×512 reinterpret(Gray{Float32}, ::Array{Float32,2}):
#  Gray{Float32}(0.635324)  Gray{Float32}(0.637317)  …  Gray{Float32}(0.600603)
#  Gray{Float32}(0.635426)  Gray{Float32}(0.63742)      Gray{Float32}(0.600692)
#  Gray{Float32}(0.636873)  Gray{Float32}(0.638872)     Gray{Float32}(0.602001)
#  Gray{Float32}(0.637949)  Gray{Float32}(0.639951)     Gray{Float32}(0.602978)
#  Gray{Float32}(0.635454)  Gray{Float32}(0.637448)     Gray{Float32}(0.600667)
#  Gray{Float32}(0.63571)   Gray{Float32}(0.637704)  …  Gray{Float32}(0.600953)
#  Gray{Float32}(0.634843)  Gray{Float32}(0.636835)     Gray{Float32}(0.600103)
#  Gray{Float32}(0.63782)   Gray{Float32}(0.639822)     Gray{Float32}(0.602851)
#  Gray{Float32}(0.635942)  Gray{Float32}(0.637938)     Gray{Float32}(0.60101)
#  Gray{Float32}(0.637364)  Gray{Float32}(0.639365)     Gray{Float32}(0.602319)
#  Gray{Float32}(0.635534)  Gray{Float32}(0.637529)  …  Gray{Float32}(0.600699)
#  Gray{Float32}(0.636963)  Gray{Float32}(0.638961)     Gray{Float32}(0.602191)
#  Gray{Float32}(0.633781)  Gray{Float32}(0.635769)     Gray{Float32}(0.599313)
#  ⋮                                                 ⋱
#  Gray{Float32}(0.474798)  Gray{Float32}(0.476308)  …  Gray{Float32}(0.443035)
#  Gray{Float32}(0.470725)  Gray{Float32}(0.47222)      Gray{Float32}(0.439501)
#  Gray{Float32}(0.462564)  Gray{Float32}(0.464033)     Gray{Float32}(0.432106)
#  Gray{Float32}(0.458819)  Gray{Float32}(0.460275)     Gray{Float32}(0.428826)
#  Gray{Float32}(0.453115)  Gray{Float32}(0.454553)     Gray{Float32}(0.423538)
#  Gray{Float32}(0.454462)  Gray{Float32}(0.455905)  …  Gray{Float32}(0.424782)
#  Gray{Float32}(0.460929)  Gray{Float32}(0.462392)     Gray{Float32}(0.430692)
#  Gray{Float32}(0.472445)  Gray{Float32}(0.473945)     Gray{Float32}(0.441256)
#  Gray{Float32}(0.475301)  Gray{Float32}(0.476812)     Gray{Float32}(0.443543)
#  Gray{Float32}(0.479258)  Gray{Float32}(0.480782)     Gray{Float32}(0.44694)
#  Gray{Float32}(0.47967)   Gray{Float32}(0.481195)  …  Gray{Float32}(0.447281)
#  Gray{Float32}(0.479222)  Gray{Float32}(0.480746)     Gray{Float32}(0.446903)

# %%
test = F.U[:,1:10]*Σ[1:10,1:10]*F.Vt[1:10, :]
colorview(Gray, test)
# Out:
# 512×512 reinterpret(Gray{Float32}, ::Array{Float32,2}):
#  Gray{Float32}(0.619796)  Gray{Float32}(0.621711)  …  Gray{Float32}(0.588685)
#  Gray{Float32}(0.619765)  Gray{Float32}(0.621688)     Gray{Float32}(0.588776)
#  Gray{Float32}(0.620704)  Gray{Float32}(0.622639)     Gray{Float32}(0.590288)
#  Gray{Float32}(0.621482)  Gray{Float32}(0.623426)     Gray{Float32}(0.591495)
#  Gray{Float32}(0.619364)  Gray{Float32}(0.621287)     Gray{Float32}(0.589113)
#  Gray{Float32}(0.62007)   Gray{Float32}(0.621984)  …  Gray{Float32}(0.589228)
#  Gray{Float32}(0.618974)  Gray{Float32}(0.620894)     Gray{Float32}(0.588684)
#  Gray{Float32}(0.621322)  Gray{Float32}(0.623277)     Gray{Float32}(0.591383)
#  Gray{Float32}(0.61855)   Gray{Float32}(0.620549)     Gray{Float32}(0.588705)
#  Gray{Float32}(0.619027)  Gray{Float32}(0.621057)     Gray{Float32}(0.589335)
#  Gray{Float32}(0.617575)  Gray{Float32}(0.619545)  …  Gray{Float32}(0.588133)
#  Gray{Float32}(0.61922)   Gray{Float32}(0.621137)     Gray{Float32}(0.590027)
#  Gray{Float32}(0.615279)  Gray{Float32}(0.617231)     Gray{Float32}(0.587034)
#  ⋮                                                 ⋱
#  Gray{Float32}(0.468352)  Gray{Float32}(0.473865)  …  Gray{Float32}(0.416111)
#  Gray{Float32}(0.462402)  Gray{Float32}(0.468006)     Gray{Float32}(0.411527)
#  Gray{Float32}(0.459419)  Gray{Float32}(0.464891)     Gray{Float32}(0.394842)
#  Gray{Float32}(0.462405)  Gray{Float32}(0.467623)     Gray{Float32}(0.384227)
#  Gray{Float32}(0.461639)  Gray{Float32}(0.466418)     Gray{Float32}(0.384928)
#  Gray{Float32}(0.466916)  Gray{Float32}(0.471338)  …  Gray{Float32}(0.395062)
#  Gray{Float32}(0.475207)  Gray{Float32}(0.479656)     Gray{Float32}(0.40599)
#  Gray{Float32}(0.488806)  Gray{Float32}(0.493348)     Gray{Float32}(0.418806)
#  Gray{Float32}(0.497314)  Gray{Float32}(0.50169)      Gray{Float32}(0.417962)
#  Gray{Float32}(0.506436)  Gray{Float32}(0.510646)     Gray{Float32}(0.417364)
#  Gray{Float32}(0.507233)  Gray{Float32}(0.511444)  …  Gray{Float32}(0.41705)
#  Gray{Float32}(0.506136)  Gray{Float32}(0.510371)     Gray{Float32}(0.417111)

# %%
test = F.U[:,1:20]*Σ[1:20,1:20]*F.Vt[1:20, :]
colorview(Gray, test)
# Out:
# 512×512 reinterpret(Gray{Float32}, ::Array{Float32,2}):
#  Gray{Float32}(0.61171)   Gray{Float32}(0.610862)  …  Gray{Float32}(0.586641)
#  Gray{Float32}(0.611581)  Gray{Float32}(0.610785)     Gray{Float32}(0.586771)
#  Gray{Float32}(0.611633)  Gray{Float32}(0.611024)     Gray{Float32}(0.58865)
#  Gray{Float32}(0.611978)  Gray{Float32}(0.611525)     Gray{Float32}(0.590089)
#  Gray{Float32}(0.610504)  Gray{Float32}(0.609911)     Gray{Float32}(0.58728)
#  Gray{Float32}(0.611986)  Gray{Float32}(0.611225)  …  Gray{Float32}(0.587024)
#  Gray{Float32}(0.610397)  Gray{Float32}(0.609792)     Gray{Float32}(0.586846)
#  Gray{Float32}(0.612302)  Gray{Float32}(0.611861)     Gray{Float32}(0.589912)
#  Gray{Float32}(0.609461)  Gray{Float32}(0.608887)     Gray{Float32}(0.587157)
#  Gray{Float32}(0.609973)  Gray{Float32}(0.609216)     Gray{Float32}(0.58755)
#  Gray{Float32}(0.60841)   Gray{Float32}(0.607607)  …  Gray{Float32}(0.585655)
#  Gray{Float32}(0.609927)  Gray{Float32}(0.609104)     Gray{Float32}(0.587033)
#  Gray{Float32}(0.605994)  Gray{Float32}(0.605175)     Gray{Float32}(0.583956)
#  ⋮                                                 ⋱
#  Gray{Float32}(0.459555)  Gray{Float32}(0.468569)  …  Gray{Float32}(0.43435)
#  Gray{Float32}(0.44737)   Gray{Float32}(0.455957)     Gray{Float32}(0.43158)
#  Gray{Float32}(0.433999)  Gray{Float32}(0.44266)      Gray{Float32}(0.416023)
#  Gray{Float32}(0.42929)   Gray{Float32}(0.43791)      Gray{Float32}(0.406028)
#  Gray{Float32}(0.433243)  Gray{Float32}(0.440824)     Gray{Float32}(0.405967)
#  Gray{Float32}(0.444746)  Gray{Float32}(0.451386)  …  Gray{Float32}(0.414795)
#  Gray{Float32}(0.450263)  Gray{Float32}(0.457324)     Gray{Float32}(0.423984)
#  Gray{Float32}(0.460287)  Gray{Float32}(0.467897)     Gray{Float32}(0.435874)
#  Gray{Float32}(0.470824)  Gray{Float32}(0.478042)     Gray{Float32}(0.436964)
#  Gray{Float32}(0.482883)  Gray{Float32}(0.489601)     Gray{Float32}(0.438545)
#  Gray{Float32}(0.48392)   Gray{Float32}(0.490604)  …  Gray{Float32}(0.438464)
#  Gray{Float32}(0.482502)  Gray{Float32}(0.489235)     Gray{Float32}(0.438302)

# %%
test = F.U[:,1:30]*Σ[1:30,1:30]*F.Vt[1:30, :]
colorview(Gray, test)
# Out:
# 512×512 reinterpret(Gray{Float32}, ::Array{Float32,2}):
#  Gray{Float32}(0.608245)  Gray{Float32}(0.607368)  …  Gray{Float32}(0.591045)
#  Gray{Float32}(0.608068)  Gray{Float32}(0.6072)       Gray{Float32}(0.591394)
#  Gray{Float32}(0.607674)  Gray{Float32}(0.606795)     Gray{Float32}(0.593582)
#  Gray{Float32}(0.60783)   Gray{Float32}(0.606937)     Gray{Float32}(0.595697)
#  Gray{Float32}(0.606681)  Gray{Float32}(0.605832)     Gray{Float32}(0.592725)
#  Gray{Float32}(0.608663)  Gray{Float32}(0.607886)  …  Gray{Float32}(0.592055)
#  Gray{Float32}(0.606692)  Gray{Float32}(0.605916)     Gray{Float32}(0.592227)
#  Gray{Float32}(0.608177)  Gray{Float32}(0.607372)     Gray{Float32}(0.595196)
#  Gray{Float32}(0.604921)  Gray{Float32}(0.603914)     Gray{Float32}(0.590808)
#  Gray{Float32}(0.605073)  Gray{Float32}(0.603853)     Gray{Float32}(0.589378)
#  Gray{Float32}(0.603224)  Gray{Float32}(0.602169)  …  Gray{Float32}(0.586122)
#  Gray{Float32}(0.604688)  Gray{Float32}(0.603841)     Gray{Float32}(0.586895)
#  Gray{Float32}(0.600849)  Gray{Float32}(0.599927)     Gray{Float32}(0.584961)
#  ⋮                                                 ⋱
#  Gray{Float32}(0.468863)  Gray{Float32}(0.478887)  …  Gray{Float32}(0.430481)
#  Gray{Float32}(0.450689)  Gray{Float32}(0.460897)     Gray{Float32}(0.430146)
#  Gray{Float32}(0.433615)  Gray{Float32}(0.444651)     Gray{Float32}(0.411602)
#  Gray{Float32}(0.426574)  Gray{Float32}(0.437859)     Gray{Float32}(0.398464)
#  Gray{Float32}(0.43048)   Gray{Float32}(0.439379)     Gray{Float32}(0.399322)
#  Gray{Float32}(0.442822)  Gray{Float32}(0.449931)  …  Gray{Float32}(0.410048)
#  Gray{Float32}(0.447657)  Gray{Float32}(0.457429)     Gray{Float32}(0.419256)
#  Gray{Float32}(0.457872)  Gray{Float32}(0.471069)     Gray{Float32}(0.431705)
#  Gray{Float32}(0.471264)  Gray{Float32}(0.485584)     Gray{Float32}(0.437703)
#  Gray{Float32}(0.486371)  Gray{Float32}(0.501046)     Gray{Float32}(0.444245)
#  Gray{Float32}(0.487437)  Gray{Float32}(0.502143)  …  Gray{Float32}(0.444854)
#  Gray{Float32}(0.485554)  Gray{Float32}(0.500104)     Gray{Float32}(0.444069)

# %%
test = F.U[:,1:40]*Σ[1:40,1:40]*F.Vt[1:40, :]
colorview(Gray, test)
# Out:
# 512×512 reinterpret(Gray{Float32}, ::Array{Float32,2}):
#  Gray{Float32}(0.607853)  Gray{Float32}(0.606597)  …  Gray{Float32}(0.595428)
#  Gray{Float32}(0.607564)  Gray{Float32}(0.606406)     Gray{Float32}(0.595708)
#  Gray{Float32}(0.606826)  Gray{Float32}(0.605919)     Gray{Float32}(0.597871)
#  Gray{Float32}(0.606738)  Gray{Float32}(0.60596)      Gray{Float32}(0.60001)
#  Gray{Float32}(0.605801)  Gray{Float32}(0.604808)     Gray{Float32}(0.597024)
#  Gray{Float32}(0.608128)  Gray{Float32}(0.606959)  …  Gray{Float32}(0.596554)
#  Gray{Float32}(0.605837)  Gray{Float32}(0.604941)     Gray{Float32}(0.597027)
#  Gray{Float32}(0.607026)  Gray{Float32}(0.606337)     Gray{Float32}(0.599807)
#  Gray{Float32}(0.603806)  Gray{Float32}(0.602863)     Gray{Float32}(0.594293)
#  Gray{Float32}(0.603866)  Gray{Float32}(0.602722)     Gray{Float32}(0.591493)
#  Gray{Float32}(0.601904)  Gray{Float32}(0.601098)  …  Gray{Float32}(0.588066)
#  Gray{Float32}(0.603174)  Gray{Float32}(0.602692)     Gray{Float32}(0.589241)
#  Gray{Float32}(0.599524)  Gray{Float32}(0.598597)     Gray{Float32}(0.588086)
#  ⋮                                                 ⋱
#  Gray{Float32}(0.480875)  Gray{Float32}(0.485693)  …  Gray{Float32}(0.385461)
#  Gray{Float32}(0.457726)  Gray{Float32}(0.464805)     Gray{Float32}(0.384044)
#  Gray{Float32}(0.435322)  Gray{Float32}(0.445632)     Gray{Float32}(0.364951)
#  Gray{Float32}(0.424659)  Gray{Float32}(0.437007)     Gray{Float32}(0.356267)
#  Gray{Float32}(0.430905)  Gray{Float32}(0.440309)     Gray{Float32}(0.372558)
#  Gray{Float32}(0.446547)  Gray{Float32}(0.45333)   …  Gray{Float32}(0.399785)
#  Gray{Float32}(0.450631)  Gray{Float32}(0.460857)     Gray{Float32}(0.415294)
#  Gray{Float32}(0.45966)   Gray{Float32}(0.474655)     Gray{Float32}(0.434291)
#  Gray{Float32}(0.474207)  Gray{Float32}(0.49157)      Gray{Float32}(0.458319)
#  Gray{Float32}(0.490677)  Gray{Float32}(0.509348)     Gray{Float32}(0.481337)
#  Gray{Float32}(0.491885)  Gray{Float32}(0.510703)  …  Gray{Float32}(0.484025)
#  Gray{Float32}(0.489688)  Gray{Float32}(0.508201)     Gray{Float32}(0.48149)

# %%
test = F.U[:,1:50]*Σ[1:50,1:50]*F.Vt[1:50, :]
colorview(Gray, test)
# Out:
# 512×512 reinterpret(Gray{Float32}, ::Array{Float32,2}):
#  Gray{Float32}(0.608696)  Gray{Float32}(0.607855)  …  Gray{Float32}(0.59774)
#  Gray{Float32}(0.608343)  Gray{Float32}(0.607604)     Gray{Float32}(0.597838)
#  Gray{Float32}(0.607028)  Gray{Float32}(0.606846)     Gray{Float32}(0.599637)
#  Gray{Float32}(0.606519)  Gray{Float32}(0.606708)     Gray{Float32}(0.601346)
#  Gray{Float32}(0.605825)  Gray{Float32}(0.605692)     Gray{Float32}(0.59877)
#  Gray{Float32}(0.608584)  Gray{Float32}(0.608041)  …  Gray{Float32}(0.598738)
#  Gray{Float32}(0.606043)  Gray{Float32}(0.605922)     Gray{Float32}(0.598658)
#  Gray{Float32}(0.606791)  Gray{Float32}(0.607116)     Gray{Float32}(0.600931)
#  Gray{Float32}(0.603451)  Gray{Float32}(0.603293)     Gray{Float32}(0.595405)
#  Gray{Float32}(0.603441)  Gray{Float32}(0.602869)     Gray{Float32}(0.592579)
#  Gray{Float32}(0.601516)  Gray{Float32}(0.601421)  …  Gray{Float32}(0.588493)
#  Gray{Float32}(0.602835)  Gray{Float32}(0.603217)     Gray{Float32}(0.589154)
#  Gray{Float32}(0.599207)  Gray{Float32}(0.599104)     Gray{Float32}(0.588844)
#  ⋮                                                 ⋱
#  Gray{Float32}(0.483458)  Gray{Float32}(0.484414)  …  Gray{Float32}(0.397049)
#  Gray{Float32}(0.462236)  Gray{Float32}(0.465529)     Gray{Float32}(0.385937)
#  Gray{Float32}(0.434007)  Gray{Float32}(0.443512)     Gray{Float32}(0.367161)
#  Gray{Float32}(0.416586)  Gray{Float32}(0.431777)     Gray{Float32}(0.361822)
#  Gray{Float32}(0.421089)  Gray{Float32}(0.436039)     Gray{Float32}(0.380796)
#  Gray{Float32}(0.437371)  Gray{Float32}(0.450716)  …  Gray{Float32}(0.409835)
#  Gray{Float32}(0.444885)  Gray{Float32}(0.458541)     Gray{Float32}(0.425449)
#  Gray{Float32}(0.457282)  Gray{Float32}(0.471745)     Gray{Float32}(0.441039)
#  Gray{Float32}(0.471492)  Gray{Float32}(0.486909)     Gray{Float32}(0.453544)
#  Gray{Float32}(0.486567)  Gray{Float32}(0.502852)     Gray{Float32}(0.465438)
#  Gray{Float32}(0.487858)  Gray{Float32}(0.504045)  …  Gray{Float32}(0.46694)
#  Gray{Float32}(0.485695)  Gray{Float32}(0.501657)     Gray{Float32}(0.466011)

# %%
test = F.U[:,1:100]*Σ[1:100,1:100]*F.Vt[1:100, :]
colorview(Gray, test)
# Out:
# 512×512 reinterpret(Gray{Float32}, ::Array{Float32,2}):
#  Gray{Float32}(0.612715)  Gray{Float32}(0.612631)  …  Gray{Float32}(0.596565)
#  Gray{Float32}(0.612127)  Gray{Float32}(0.611736)     Gray{Float32}(0.596394)
#  Gray{Float32}(0.610496)  Gray{Float32}(0.608459)     Gray{Float32}(0.599232)
#  Gray{Float32}(0.610578)  Gray{Float32}(0.607052)     Gray{Float32}(0.601684)
#  Gray{Float32}(0.609585)  Gray{Float32}(0.608113)     Gray{Float32}(0.599071)
#  Gray{Float32}(0.612066)  Gray{Float32}(0.612386)  …  Gray{Float32}(0.598973)
#  Gray{Float32}(0.610425)  Gray{Float32}(0.608808)     Gray{Float32}(0.599915)
#  Gray{Float32}(0.611185)  Gray{Float32}(0.607635)     Gray{Float32}(0.601853)
#  Gray{Float32}(0.603917)  Gray{Float32}(0.602633)     Gray{Float32}(0.596311)
#  Gray{Float32}(0.599711)  Gray{Float32}(0.60111)      Gray{Float32}(0.593607)
#  Gray{Float32}(0.598406)  Gray{Float32}(0.600181)  …  Gray{Float32}(0.586063)
#  Gray{Float32}(0.601146)  Gray{Float32}(0.602733)     Gray{Float32}(0.583041)
#  Gray{Float32}(0.597104)  Gray{Float32}(0.599882)     Gray{Float32}(0.581556)
#  ⋮                                                 ⋱
#  Gray{Float32}(0.500781)  Gray{Float32}(0.479728)  …  Gray{Float32}(0.37104)
#  Gray{Float32}(0.449728)  Gray{Float32}(0.447811)     Gray{Float32}(0.375574)
#  Gray{Float32}(0.411389)  Gray{Float32}(0.430533)     Gray{Float32}(0.383308)
#  Gray{Float32}(0.396121)  Gray{Float32}(0.428775)     Gray{Float32}(0.403825)
#  Gray{Float32}(0.425573)  Gray{Float32}(0.44115)      Gray{Float32}(0.43799)
#  Gray{Float32}(0.464804)  Gray{Float32}(0.462666)  …  Gray{Float32}(0.469547)
#  Gray{Float32}(0.462686)  Gray{Float32}(0.476484)     Gray{Float32}(0.465544)
#  Gray{Float32}(0.458054)  Gray{Float32}(0.488894)     Gray{Float32}(0.453463)
#  Gray{Float32}(0.465102)  Gray{Float32}(0.487326)     Gray{Float32}(0.43906)
#  Gray{Float32}(0.477077)  Gray{Float32}(0.486913)     Gray{Float32}(0.43073)
#  Gray{Float32}(0.477332)  Gray{Float32}(0.486028)  …  Gray{Float32}(0.429468)
#  Gray{Float32}(0.47603)   Gray{Float32}(0.485714)     Gray{Float32}(0.432271)
