# %%
using Plots; pyplot()
# Out:
# ┌ Info: Precompiling PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee]
# └ @ Base loading.jl:1192
# ┌ Info: Installing matplotlib via the Conda matplotlib package...
# └ @ PyCall /Users/randydavila/.julia/packages/PyCall/0jMpb/src/PyCall.jl:653
# ┌ Info: Running `conda install -y matplotlib` in root environment
# └ @ Conda /Users/randydavila/.julia/packages/Conda/CpuvI/src/Conda.jl:112
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /Users/randydavila/.julia/conda/3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cycler-0.10.0              |             py_1           8 KB  conda-forge
#     freetype-2.9.1             |    h597ad8a_1005         868 KB  conda-forge
#     kiwisolver-1.0.1           |py36h04f5b5a_1002          56 KB  conda-forge
# ...

# %%
f(x,y)=x^2 +y^2
# Out:
# f (generic function with 1 method)

# %%
plot(
       contour(f; levels = range(0,stop=5,length=5)),
       size = (800, 400)
       )
# Out:
# f is not a Function, or is not defined at any of the values [-5.0, -1.0, 0.0, 0.01]
#
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] tryrange(::typeof(f), ::Array{Float64,1}) at /Users/randydavila/.julia/packages/Plots/UQI78/src/series.jl:420
#  [3] macro expansion at /Users/randydavila/.julia/packages/Plots/UQI78/src/series.jl:397 [inlined]
#  [4] apply_recipe(::Dict{Symbol,Any}, ::typeof(f)) at /Users/randydavila/.julia/packages/RecipesBase/Uz5AO/src/RecipesBase.jl:275
#  [5] _process_userrecipes(::Plots.Plot{Plots.PyPlotBackend}, ::Dict{Symbol,Any}, ::Tuple{typeof(f)}) at /Users/randydavila/.julia/packages/Plots/UQI78/src/pipeline.jl:83
#  [6] _plot!(::Plots.Plot{Plots.PyPlotBackend}, ::Dict{Symbol,Any}, ::Tuple{typeof(f)}) at /Users/randydavila/.julia/packages/Plots/UQI78/src/plot.jl:178
# ...

# %%
range(0,stop=2*pi,length=10)
# Out:
# 0.0:0.6981317007977318:6.283185307179586

# %%
gr()
x = range(-100,stop=100,length=100)
y = range(-100,stop=100,length=100)
f(x,y) = (2*x-3)^4 + (3*x-y)^2
plot(x, y, f, st = :contour)
