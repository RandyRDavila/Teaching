# %% [markdown]
# # SVD and Image Compression
# In this notebook we show how the SVD can be used to compress images. With this aim in mind, it should be noted that images can be represented as multidimensional arrays of numbers, i.e., matrices.

# %%
# LinearAlgebra import the svd factorization function
# Images imports the functions for converting a standard image to a matrix
# TestImages is used to import a test image
using LinearAlgebra, Images, TestImages
# Out:
# ArgumentError: Package Images not found in current path:
# - Run `import Pkg; Pkg.add("Images")` to install the Images package.
#
#
# Stacktrace:
#  [1] require(::Module, ::Symbol) at ./loading.jl:823
#  [2] top-level scope at In[1]:1

# %%
# Load a sample test image 
img = testimage("lena_gray")
# Out:
# 256×256 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.635)  Gray{N0f8}(0.635)  …  Gray{N0f8}(0.608)
#  Gray{N0f8}(0.635)  Gray{N0f8}(0.635)     Gray{N0f8}(0.608)
#  Gray{N0f8}(0.635)  Gray{N0f8}(0.635)     Gray{N0f8}(0.608)
#  Gray{N0f8}(0.627)  Gray{N0f8}(0.639)     Gray{N0f8}(0.251)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.62)      Gray{N0f8}(0.184)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.612)  …  Gray{N0f8}(0.2)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.616)     Gray{N0f8}(0.188)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.624)     Gray{N0f8}(0.192)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.608)     Gray{N0f8}(0.192)
#  Gray{N0f8}(0.616)  Gray{N0f8}(0.624)     Gray{N0f8}(0.18)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.608)  …  Gray{N0f8}(0.18)
#  Gray{N0f8}(0.624)  Gray{N0f8}(0.608)     Gray{N0f8}(0.204)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.616)     Gray{N0f8}(0.212)
#  ⋮                                     ⋱  ⋮
#  Gray{N0f8}(0.216)  Gray{N0f8}(0.302)     Gray{N0f8}(0.227)
#  Gray{N0f8}(0.169)  Gray{N0f8}(0.239)  …  Gray{N0f8}(0.235)
#  Gray{N0f8}(0.173)  Gray{N0f8}(0.212)     Gray{N0f8}(0.192)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.196)     Gray{N0f8}(0.196)
#  Gray{N0f8}(0.196)  Gray{N0f8}(0.227)     Gray{N0f8}(0.231)
#  Gray{N0f8}(0.196)  Gray{N0f8}(0.263)     Gray{N0f8}(0.18)
#  Gray{N0f8}(0.204)  Gray{N0f8}(0.22)   …  Gray{N0f8}(0.208)
#  Gray{N0f8}(0.188)  Gray{N0f8}(0.22)      Gray{N0f8}(0.275)
#  Gray{N0f8}(0.188)  Gray{N0f8}(0.208)     Gray{N0f8}(0.306)
#  Gray{N0f8}(0.188)  Gray{N0f8}(0.224)     Gray{N0f8}(0.345)
#  Gray{N0f8}(0.18)   Gray{N0f8}(0.196)     Gray{N0f8}(0.384)
#  Gray{N0f8}(0.173)  Gray{N0f8}(0.216)  …  Gray{N0f8}(0.412)

# %%
# Convert the image to a matrix pf floating point numbers
A = float(channelview(img))
# Out:
# 256×256 Array{Float32,2}:
#  0.635294  0.635294  0.635294  0.639216  …  0.658824  0.670588  0.607843
#  0.635294  0.635294  0.635294  0.639216     0.658824  0.670588  0.607843
#  0.635294  0.635294  0.635294  0.639216     0.658824  0.670588  0.607843
#  0.627451  0.639216  0.627451  0.623529     0.478431  0.360784  0.25098
#  0.607843  0.619608  0.623529  0.615686     0.25098   0.196078  0.184314
#  0.611765  0.611765  0.611765  0.607843  …  0.196078  0.184314  0.2
#  0.619608  0.615686  0.615686  0.623529     0.180392  0.188235  0.188235
#  0.619608  0.623529  0.607843  0.619608     0.192157  0.211765  0.192157
#  0.611765  0.607843  0.619608  0.615686     0.192157  0.176471  0.192157
#  0.615686  0.623529  0.619608  0.603922     0.196078  0.188235  0.180392
#  0.611765  0.607843  0.607843  0.611765  …  0.184314  0.180392  0.180392
#  0.623529  0.607843  0.6       0.611765     0.188235  0.192157  0.203922
#  0.611765  0.615686  0.596078  0.623529     0.192157  0.215686  0.211765
#  ⋮                                       ⋱                      ⋮
#  0.215686  0.301961  0.368627  0.439216     0.270588  0.278431  0.227451
#  0.168627  0.239216  0.313726  0.372549  …  0.25098   0.25098   0.235294
#  0.172549  0.211765  0.247059  0.309804     0.25098   0.223529  0.192157
#  0.2       0.196078  0.243137  0.266667     0.239216  0.207843  0.196078
#  0.196078  0.227451  0.211765  0.254902     0.227451  0.219608  0.231373
#  0.196078  0.262745  0.247059  0.25098      0.196078  0.2       0.180392
#  0.203922  0.219608  0.227451  0.203922  …  0.219608  0.196078  0.207843
#  0.188235  0.219608  0.239216  0.196078     0.223529  0.215686  0.27451
#  0.188235  0.207843  0.207843  0.2          0.239216  0.27451   0.305882
#  0.188235  0.223529  0.211765  0.196078     0.294118  0.380392  0.345098
#  0.180392  0.196078  0.203922  0.196078     0.34902   0.392157  0.384314
#  0.172549  0.215686  0.211765  0.196078  …  0.380392  0.392157  0.411765

# %% [markdown]
# Next we use the svd function from the LinearAlgebra library to find the SVD factorization of A.

# %%
# Compute the SVD-factorization 
F = svd(A)
# Out:
# SVD{Float32,Float32,Array{Float32,2}}(Float32[-0.0668859 -0.0395316 … 0.224415 -0.785073; -0.0668861 -0.0395315 … 0.567744 0.586832; … ; -0.0589755 -0.0678707 … -0.000153285 4.24609e-5; -0.058857 -0.0676591 … 0.000146978 -2.17184e-5], Float32[126.896, 20.7557, 16.0191, 12.7106, 11.5424, 10.9307, 8.97189, 8.0203, 6.61766, 6.23357  …  0.0173814, 0.0153016, 0.0143065, 0.011184, 0.00778687, 0.00600138, 0.00499519, 0.00400654, 2.89123e-5, 7.02631e-6], Float32[-0.0472081 -0.0474649 … -0.0647492 -0.0646326; -0.0378488 -0.040234 … 0.11633 0.113213; … ; -0.037312 -0.122476 … -0.0449005 0.0493098; 0.0 0.0663377 … -0.0980778 0.0767928])

# %%
# Set the diagonal
Σ = Diagonal(F.S)
# Out:
# 256×256 Diagonal{Float32,Array{Float32,1}}:
#  126.896    ⋅        ⋅        ⋅      …   ⋅           ⋅           ⋅
#     ⋅     20.7557    ⋅        ⋅          ⋅           ⋅           ⋅
#     ⋅       ⋅      16.0191    ⋅          ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅      12.7106      ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅          ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅      …   ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅          ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅          ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅          ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅          ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅      …   ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅          ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅          ⋅           ⋅           ⋅
#    ⋮                                 ⋱                          ⋮
#     ⋅       ⋅        ⋅        ⋅          ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅      …   ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅          ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅          ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅          ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅          ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅      …   ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅          ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅          ⋅           ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅         0.00400654   ⋅           ⋅
#     ⋅       ⋅        ⋅        ⋅          ⋅          2.89123e-5   ⋅
#     ⋅       ⋅        ⋅        ⋅      …   ⋅           ⋅          7.02631e-6

# %%
test = F.U[:,1:2]*Σ[1:2,1:2]*F.Vt[1:2, :]
colorview(Gray, test)
# Out:
# 256×256 reinterpret(Gray{Float32}, ::Array{Float32,2}):
#  Gray{Float32}(0.431737)  Gray{Float32}(0.435874)  …  Gray{Float32}(0.455683)
#  Gray{Float32}(0.431738)  Gray{Float32}(0.435875)     Gray{Float32}(0.455684)
#  Gray{Float32}(0.431738)  Gray{Float32}(0.435875)     Gray{Float32}(0.455684)
#  Gray{Float32}(0.430154)  Gray{Float32}(0.434448)     Gray{Float32}(0.441036)
#  Gray{Float32}(0.430594)  Gray{Float32}(0.435014)     Gray{Float32}(0.432196)
#  Gray{Float32}(0.429695)  Gray{Float32}(0.434197)  …  Gray{Float32}(0.424403)
#  Gray{Float32}(0.430412)  Gray{Float32}(0.434998)     Gray{Float32}(0.419307)
#  Gray{Float32}(0.432197)  Gray{Float32}(0.436895)     Gray{Float32}(0.413989)
#  Gray{Float32}(0.432334)  Gray{Float32}(0.43708)      Gray{Float32}(0.410612)
#  Gray{Float32}(0.432233)  Gray{Float32}(0.437004)     Gray{Float32}(0.40852)
#  Gray{Float32}(0.432555)  Gray{Float32}(0.437374)  …  Gray{Float32}(0.405497)
#  Gray{Float32}(0.429813)  Gray{Float32}(0.434651)     Gray{Float32}(0.399232)
#  Gray{Float32}(0.430735)  Gray{Float32}(0.435641)     Gray{Float32}(0.395654)
#  ⋮                                                 ⋱  ⋮
#  Gray{Float32}(0.386601)  Gray{Float32}(0.391374)     Gray{Float32}(0.327138)
#  Gray{Float32}(0.385706)  Gray{Float32}(0.390463)  …  Gray{Float32}(0.326737)
#  Gray{Float32}(0.390289)  Gray{Float32}(0.395278)     Gray{Float32}(0.317329)
#  Gray{Float32}(0.391588)  Gray{Float32}(0.396671)     Gray{Float32}(0.31252)
#  Gray{Float32}(0.394177)  Gray{Float32}(0.399282)     Gray{Float32}(0.315476)
#  Gray{Float32}(0.397225)  Gray{Float32}(0.402477)     Gray{Float32}(0.30978)
#  Gray{Float32}(0.399673)  Gray{Float32}(0.405021)  …  Gray{Float32}(0.306918)
#  Gray{Float32}(0.402429)  Gray{Float32}(0.40783)      Gray{Float32}(0.307741)
#  Gray{Float32}(0.404508)  Gray{Float32}(0.409826)     Gray{Float32}(0.317788)
#  Gray{Float32}(0.407043)  Gray{Float32}(0.412345)     Gray{Float32}(0.323473)
#  Gray{Float32}(0.406612)  Gray{Float32}(0.411894)     Gray{Float32}(0.324212)
#  Gray{Float32}(0.405736)  Gray{Float32}(0.411004)  …  Gray{Float32}(0.323738)

# %%
test = F.U[:,1:10]*Σ[1:10,1:10]*F.Vt[1:10, :]
colorview(Gray, test)
# Out:
# 256×256 reinterpret(Gray{Float32}, ::Array{Float32,2}):
#  Gray{Float32}(0.553944)  Gray{Float32}(0.552526)  …  Gray{Float32}(0.433648)
#  Gray{Float32}(0.553943)  Gray{Float32}(0.552526)     Gray{Float32}(0.43365)
#  Gray{Float32}(0.553944)  Gray{Float32}(0.552527)     Gray{Float32}(0.433649)
#  Gray{Float32}(0.559131)  Gray{Float32}(0.558454)     Gray{Float32}(0.391809)
#  Gray{Float32}(0.569674)  Gray{Float32}(0.569728)     Gray{Float32}(0.364328)
#  Gray{Float32}(0.569655)  Gray{Float32}(0.570291)  …  Gray{Float32}(0.343945)
#  Gray{Float32}(0.579057)  Gray{Float32}(0.579922)     Gray{Float32}(0.327164)
#  Gray{Float32}(0.587985)  Gray{Float32}(0.589436)     Gray{Float32}(0.309904)
#  Gray{Float32}(0.599707)  Gray{Float32}(0.601558)     Gray{Float32}(0.291337)
#  Gray{Float32}(0.608041)  Gray{Float32}(0.610143)     Gray{Float32}(0.273541)
#  Gray{Float32}(0.612088)  Gray{Float32}(0.614468)  …  Gray{Float32}(0.263032)
#  Gray{Float32}(0.623439)  Gray{Float32}(0.625664)     Gray{Float32}(0.246894)
#  Gray{Float32}(0.631505)  Gray{Float32}(0.63366)      Gray{Float32}(0.235508)
#  ⋮                                                 ⋱  ⋮
#  Gray{Float32}(0.21783)   Gray{Float32}(0.241356)     Gray{Float32}(0.214004)
#  Gray{Float32}(0.188249)  Gray{Float32}(0.212253)  …  Gray{Float32}(0.222506)
#  Gray{Float32}(0.192931)  Gray{Float32}(0.21647)      Gray{Float32}(0.233375)
#  Gray{Float32}(0.193533)  Gray{Float32}(0.216687)     Gray{Float32}(0.253506)
#  Gray{Float32}(0.212588)  Gray{Float32}(0.235259)     Gray{Float32}(0.259274)
#  Gray{Float32}(0.226906)  Gray{Float32}(0.249854)     Gray{Float32}(0.245795)
#  Gray{Float32}(0.236728)  Gray{Float32}(0.259696)  …  Gray{Float32}(0.252413)
#  Gray{Float32}(0.247648)  Gray{Float32}(0.270708)     Gray{Float32}(0.243985)
#  Gray{Float32}(0.254968)  Gray{Float32}(0.277867)     Gray{Float32}(0.247974)
#  Gray{Float32}(0.277294)  Gray{Float32}(0.298953)     Gray{Float32}(0.255046)
#  Gray{Float32}(0.290012)  Gray{Float32}(0.31101)      Gray{Float32}(0.263743)
#  Gray{Float32}(0.293121)  Gray{Float32}(0.313925)  …  Gray{Float32}(0.258169)

# %%
test = F.U[:,1:20]*Σ[1:20,1:20]*F.Vt[1:20, :]
colorview(Gray, test)
# Out:
# 256×256 reinterpret(Gray{Float32}, ::Array{Float32,2}):
#  Gray{Float32}(0.562205)  Gray{Float32}(0.565577)  …  Gray{Float32}(0.42232)
#  Gray{Float32}(0.562205)  Gray{Float32}(0.565577)     Gray{Float32}(0.422322)
#  Gray{Float32}(0.562206)  Gray{Float32}(0.565578)     Gray{Float32}(0.422321)
#  Gray{Float32}(0.561276)  Gray{Float32}(0.566564)     Gray{Float32}(0.347463)
#  Gray{Float32}(0.568377)  Gray{Float32}(0.575747)     Gray{Float32}(0.30033)
#  Gray{Float32}(0.568994)  Gray{Float32}(0.577225)  …  Gray{Float32}(0.272985)
#  Gray{Float32}(0.579074)  Gray{Float32}(0.588234)     Gray{Float32}(0.251586)
#  Gray{Float32}(0.590487)  Gray{Float32}(0.599936)     Gray{Float32}(0.232945)
#  Gray{Float32}(0.599616)  Gray{Float32}(0.61098)      Gray{Float32}(0.20875)
#  Gray{Float32}(0.609126)  Gray{Float32}(0.62068)      Gray{Float32}(0.195382)
#  Gray{Float32}(0.617177)  Gray{Float32}(0.627956)  …  Gray{Float32}(0.192827)
#  Gray{Float32}(0.630187)  Gray{Float32}(0.640131)     Gray{Float32}(0.182145)
#  Gray{Float32}(0.637537)  Gray{Float32}(0.647462)     Gray{Float32}(0.183234)
#  ⋮                                                 ⋱  ⋮
#  Gray{Float32}(0.233115)  Gray{Float32}(0.26759)      Gray{Float32}(0.283239)
#  Gray{Float32}(0.193469)  Gray{Float32}(0.228212)  …  Gray{Float32}(0.262013)
#  Gray{Float32}(0.178061)  Gray{Float32}(0.211925)     Gray{Float32}(0.231324)
#  Gray{Float32}(0.168728)  Gray{Float32}(0.201322)     Gray{Float32}(0.240104)
#  Gray{Float32}(0.182602)  Gray{Float32}(0.21309)      Gray{Float32}(0.233466)
#  Gray{Float32}(0.190249)  Gray{Float32}(0.220518)     Gray{Float32}(0.198831)
#  Gray{Float32}(0.196042)  Gray{Float32}(0.22588)   …  Gray{Float32}(0.199499)
#  Gray{Float32}(0.201335)  Gray{Float32}(0.231959)     Gray{Float32}(0.198019)
#  Gray{Float32}(0.214634)  Gray{Float32}(0.244264)     Gray{Float32}(0.2139)
#  Gray{Float32}(0.245251)  Gray{Float32}(0.273207)     Gray{Float32}(0.231136)
#  Gray{Float32}(0.272803)  Gray{Float32}(0.297549)     Gray{Float32}(0.24916)
#  Gray{Float32}(0.284187)  Gray{Float32}(0.307983)  …  Gray{Float32}(0.269359)

# %%
test = F.U[:,1:30]*Σ[1:30,1:30]*F.Vt[1:30, :]
colorview(Gray, test)
# Out:
# 256×256 reinterpret(Gray{Float32}, ::Array{Float32,2}):
#  Gray{Float32}(0.559843)  Gray{Float32}(0.558612)  …  Gray{Float32}(0.484626)
#  Gray{Float32}(0.559842)  Gray{Float32}(0.558612)     Gray{Float32}(0.484628)
#  Gray{Float32}(0.559844)  Gray{Float32}(0.558613)     Gray{Float32}(0.484627)
#  Gray{Float32}(0.562203)  Gray{Float32}(0.564085)     Gray{Float32}(0.368623)
#  Gray{Float32}(0.570866)  Gray{Float32}(0.577023)     Gray{Float32}(0.283766)
#  Gray{Float32}(0.576046)  Gray{Float32}(0.582359)  …  Gray{Float32}(0.244011)
#  Gray{Float32}(0.585707)  Gray{Float32}(0.593483)     Gray{Float32}(0.214929)
#  Gray{Float32}(0.595339)  Gray{Float32}(0.601948)     Gray{Float32}(0.200946)
#  Gray{Float32}(0.602147)  Gray{Float32}(0.609629)     Gray{Float32}(0.173273)
#  Gray{Float32}(0.604702)  Gray{Float32}(0.611183)     Gray{Float32}(0.1748)
#  Gray{Float32}(0.608063)  Gray{Float32}(0.612186)  …  Gray{Float32}(0.183208)
#  Gray{Float32}(0.6164)    Gray{Float32}(0.617154)     Gray{Float32}(0.193155)
#  Gray{Float32}(0.619544)  Gray{Float32}(0.620689)     Gray{Float32}(0.206992)
#  ⋮                                                 ⋱  ⋮
#  Gray{Float32}(0.272326)  Gray{Float32}(0.313227)     Gray{Float32}(0.22344)
#  Gray{Float32}(0.228353)  Gray{Float32}(0.271215)  …  Gray{Float32}(0.217792)
#  Gray{Float32}(0.198303)  Gray{Float32}(0.242879)     Gray{Float32}(0.197476)
#  Gray{Float32}(0.173369)  Gray{Float32}(0.218506)     Gray{Float32}(0.203293)
#  Gray{Float32}(0.173945)  Gray{Float32}(0.216176)     Gray{Float32}(0.205679)
#  Gray{Float32}(0.174458)  Gray{Float32}(0.217373)     Gray{Float32}(0.184831)
#  Gray{Float32}(0.168339)  Gray{Float32}(0.208874)  …  Gray{Float32}(0.236173)
#  Gray{Float32}(0.163834)  Gray{Float32}(0.200037)     Gray{Float32}(0.271217)
#  Gray{Float32}(0.17377)   Gray{Float32}(0.202517)     Gray{Float32}(0.294207)
#  Gray{Float32}(0.198707)  Gray{Float32}(0.22038)      Gray{Float32}(0.33096)
#  Gray{Float32}(0.216574)  Gray{Float32}(0.235193)     Gray{Float32}(0.363317)
#  Gray{Float32}(0.23018)   Gray{Float32}(0.248197)  …  Gray{Float32}(0.387256)

# %%
test = F.U[:,1:40]*Σ[1:40,1:40]*F.Vt[1:40, :]
colorview(Gray, test)
# Out:
# 256×256 reinterpret(Gray{Float32}, ::Array{Float32,2}):
#  Gray{Float32}(0.586005)  Gray{Float32}(0.583624)  …  Gray{Float32}(0.52765)
#  Gray{Float32}(0.586005)  Gray{Float32}(0.583624)     Gray{Float32}(0.527651)
#  Gray{Float32}(0.586006)  Gray{Float32}(0.583626)     Gray{Float32}(0.527651)
#  Gray{Float32}(0.581662)  Gray{Float32}(0.581118)     Gray{Float32}(0.369353)
#  Gray{Float32}(0.585098)  Gray{Float32}(0.587783)     Gray{Float32}(0.26164)
#  Gray{Float32}(0.586295)  Gray{Float32}(0.589949)  …  Gray{Float32}(0.217368)
#  Gray{Float32}(0.589148)  Gray{Float32}(0.595187)     Gray{Float32}(0.185741)
#  Gray{Float32}(0.59326)   Gray{Float32}(0.599373)     Gray{Float32}(0.180315)
#  Gray{Float32}(0.593437)  Gray{Float32}(0.601895)     Gray{Float32}(0.15668)
#  Gray{Float32}(0.592503)  Gray{Float32}(0.600591)     Gray{Float32}(0.156442)
#  Gray{Float32}(0.595643)  Gray{Float32}(0.602423)  …  Gray{Float32}(0.170066)
#  Gray{Float32}(0.602169)  Gray{Float32}(0.605523)     Gray{Float32}(0.1794)
#  Gray{Float32}(0.603726)  Gray{Float32}(0.607555)     Gray{Float32}(0.187713)
#  ⋮                                                 ⋱  ⋮
#  Gray{Float32}(0.261525)  Gray{Float32}(0.308726)     Gray{Float32}(0.242509)
#  Gray{Float32}(0.232502)  Gray{Float32}(0.27927)   …  Gray{Float32}(0.238262)
#  Gray{Float32}(0.212568)  Gray{Float32}(0.256717)     Gray{Float32}(0.206436)
#  Gray{Float32}(0.189049)  Gray{Float32}(0.235624)     Gray{Float32}(0.221125)
#  Gray{Float32}(0.195498)  Gray{Float32}(0.237795)     Gray{Float32}(0.228052)
#  Gray{Float32}(0.19674)   Gray{Float32}(0.236591)     Gray{Float32}(0.199365)
#  Gray{Float32}(0.184539)  Gray{Float32}(0.221517)  …  Gray{Float32}(0.238673)
#  Gray{Float32}(0.176962)  Gray{Float32}(0.208523)     Gray{Float32}(0.252468)
#  Gray{Float32}(0.187647)  Gray{Float32}(0.214416)     Gray{Float32}(0.293243)
#  Gray{Float32}(0.207959)  Gray{Float32}(0.229832)     Gray{Float32}(0.340627)
#  Gray{Float32}(0.207917)  Gray{Float32}(0.22897)      Gray{Float32}(0.395691)
#  Gray{Float32}(0.215004)  Gray{Float32}(0.235361)  …  Gray{Float32}(0.41261)

# %%
test = F.U[:,1:50]*Σ[1:50,1:50]*F.Vt[1:50, :]
colorview(Gray, test)
# Out:
# 256×256 reinterpret(Gray{Float32}, ::Array{Float32,2}):
#  Gray{Float32}(0.59919)   Gray{Float32}(0.596511)  …  Gray{Float32}(0.543875)
#  Gray{Float32}(0.59919)   Gray{Float32}(0.596511)     Gray{Float32}(0.543876)
#  Gray{Float32}(0.599191)  Gray{Float32}(0.596512)     Gray{Float32}(0.543876)
#  Gray{Float32}(0.598666)  Gray{Float32}(0.595726)     Gray{Float32}(0.363109)
#  Gray{Float32}(0.602619)  Gray{Float32}(0.60042)      Gray{Float32}(0.249267)
#  Gray{Float32}(0.604394)  Gray{Float32}(0.60477)   …  Gray{Float32}(0.213851)
#  Gray{Float32}(0.602549)  Gray{Float32}(0.605652)     Gray{Float32}(0.189153)
#  Gray{Float32}(0.60533)   Gray{Float32}(0.609893)     Gray{Float32}(0.191203)
#  Gray{Float32}(0.599049)  Gray{Float32}(0.608156)     Gray{Float32}(0.166904)
#  Gray{Float32}(0.594384)  Gray{Float32}(0.604133)     Gray{Float32}(0.158449)
#  Gray{Float32}(0.594215)  Gray{Float32}(0.603143)  …  Gray{Float32}(0.168729)
#  Gray{Float32}(0.598563)  Gray{Float32}(0.60504)      Gray{Float32}(0.179193)
#  Gray{Float32}(0.600446)  Gray{Float32}(0.607111)     Gray{Float32}(0.191465)
#  ⋮                                                 ⋱  ⋮
#  Gray{Float32}(0.252364)  Gray{Float32}(0.302205)     Gray{Float32}(0.245567)
#  Gray{Float32}(0.210396)  Gray{Float32}(0.256579)  …  Gray{Float32}(0.239363)
#  Gray{Float32}(0.208058)  Gray{Float32}(0.24991)      Gray{Float32}(0.196555)
#  Gray{Float32}(0.185559)  Gray{Float32}(0.224913)     Gray{Float32}(0.191957)
#  Gray{Float32}(0.184874)  Gray{Float32}(0.220364)     Gray{Float32}(0.213502)
#  Gray{Float32}(0.185839)  Gray{Float32}(0.223547)     Gray{Float32}(0.186501)
#  Gray{Float32}(0.175055)  Gray{Float32}(0.212719)  …  Gray{Float32}(0.234279)
#  Gray{Float32}(0.177874)  Gray{Float32}(0.210657)     Gray{Float32}(0.257222)
#  Gray{Float32}(0.180932)  Gray{Float32}(0.209348)     Gray{Float32}(0.299041)
#  Gray{Float32}(0.214886)  Gray{Float32}(0.240781)     Gray{Float32}(0.342686)
#  Gray{Float32}(0.213191)  Gray{Float32}(0.239222)     Gray{Float32}(0.387617)
#  Gray{Float32}(0.204647)  Gray{Float32}(0.225618)  …  Gray{Float32}(0.390226)

# %%
test = F.U[:,1:100]*Σ[1:100,1:100]*F.Vt[1:100, :]
colorview(Gray, test)
# Out:
# 256×256 reinterpret(Gray{Float32}, ::Array{Float32,2}):
#  Gray{Float32}(0.633217)  Gray{Float32}(0.637255)  …  Gray{Float32}(0.605607)
#  Gray{Float32}(0.633218)  Gray{Float32}(0.637255)     Gray{Float32}(0.605608)
#  Gray{Float32}(0.633219)  Gray{Float32}(0.637257)     Gray{Float32}(0.605608)
#  Gray{Float32}(0.615183)  Gray{Float32}(0.621416)     Gray{Float32}(0.313801)
#  Gray{Float32}(0.613898)  Gray{Float32}(0.617876)     Gray{Float32}(0.178891)
#  Gray{Float32}(0.611828)  Gray{Float32}(0.610918)  …  Gray{Float32}(0.171529)
#  Gray{Float32}(0.604801)  Gray{Float32}(0.607022)     Gray{Float32}(0.168476)
#  Gray{Float32}(0.60625)   Gray{Float32}(0.608428)     Gray{Float32}(0.186171)
#  Gray{Float32}(0.605199)  Gray{Float32}(0.605037)     Gray{Float32}(0.188434)
#  Gray{Float32}(0.607273)  Gray{Float32}(0.607496)     Gray{Float32}(0.184911)
#  Gray{Float32}(0.607557)  Gray{Float32}(0.606077)  …  Gray{Float32}(0.195261)
#  Gray{Float32}(0.623338)  Gray{Float32}(0.615492)     Gray{Float32}(0.201902)
#  Gray{Float32}(0.613504)  Gray{Float32}(0.612075)     Gray{Float32}(0.202295)
#  ⋮                                                 ⋱  ⋮
#  Gray{Float32}(0.231488)  Gray{Float32}(0.30241)      Gray{Float32}(0.233796)
#  Gray{Float32}(0.171486)  Gray{Float32}(0.239472)  …  Gray{Float32}(0.226114)
#  Gray{Float32}(0.182294)  Gray{Float32}(0.228936)     Gray{Float32}(0.210304)
#  Gray{Float32}(0.187205)  Gray{Float32}(0.216203)     Gray{Float32}(0.197163)
#  Gray{Float32}(0.196264)  Gray{Float32}(0.216472)     Gray{Float32}(0.226582)
#  Gray{Float32}(0.209894)  Gray{Float32}(0.23862)      Gray{Float32}(0.18002)
#  Gray{Float32}(0.197336)  Gray{Float32}(0.232143)  …  Gray{Float32}(0.188071)
#  Gray{Float32}(0.192178)  Gray{Float32}(0.220142)     Gray{Float32}(0.263687)
#  Gray{Float32}(0.170302)  Gray{Float32}(0.192865)     Gray{Float32}(0.322682)
#  Gray{Float32}(0.186811)  Gray{Float32}(0.213473)     Gray{Float32}(0.364463)
#  Gray{Float32}(0.194796)  Gray{Float32}(0.225334)     Gray{Float32}(0.393381)
#  Gray{Float32}(0.174592)  Gray{Float32}(0.206025)  …  Gray{Float32}(0.384959)
