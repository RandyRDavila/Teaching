# %%
using Plots
M = [1 1 2 3 3 1.0; 1 2 3 2 1 1.0]
# Out:
# 2×6 Array{Float64,2}:
#  1.0  1.0  2.0  3.0  3.0  1.0
#  1.0  2.0  3.0  2.0  1.0  1.0

# %%
plot([x for x in zip(M[1,:], M[2,:])])

# %%
#plot([x for x in zip(M[1,:], M[2,:])])
A1 = [4 0; 0 4.0]
N = A1*M
plot!([x for x in zip(N[1,:], N[2,:])])

# %%
plot([x for x in zip(M[1,:], M[2,:])])
A1 = [2 0; 0 2]
N = A1*M
plot!([x for x in zip(N[1,:], N[2,:])])
A2 = [3 0; 0 3]
N = A2*M
plot!([x for x in zip(N[1,:], N[2,:])])
A3 = [4 0; 0 4]
N = A3*M
plot!([x for x in zip(N[1,:], N[2,:])])
A4 = [5 0; 0 5]
N = A4*M
plot!([x for x in zip(N[1,:], N[2,:])])

# %%
A1 = [cos(π) 0; 0 sin(π)]
N = A1*M
plot([x for x in zip(N[1,:], N[2,:])])
# Out:
# ┌ Warning: No strict ticks found
# └ @ PlotUtils /Users/randydavila/.julia/packages/PlotUtils/GxT73/src/ticks.jl:173
# ┌ Warning: No strict ticks found
# └ @ PlotUtils /Users/randydavila/.julia/packages/PlotUtils/GxT73/src/ticks.jl:173
# ┌ Warning: No strict ticks found
# └ @ PlotUtils /Users/randydavila/.julia/packages/PlotUtils/GxT73/src/ticks.jl:173

# %%
f(x) = x^2
# Out:
# f (generic function with 1 method)

# %%
using Plots
plot(f, 0, 4)

# %%
g(x) = x + 1
plot!(g)
